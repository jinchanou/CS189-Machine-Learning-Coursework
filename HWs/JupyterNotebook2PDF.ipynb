# %% [markdown]
# ## Notebook to PDF converter
#
# **If running locally:**.
# 1. Instead of colab, download the notebook by clicking 'save as .ipynb'
#
# 2. Open the notebook on your jupyter notebook by going into the folder that contains your notebook (run ```jupyter notebook``` in the terminal. This will allow you to open your notebook in the ```localhost``` environemnt.
#
# 3. Then, click download as .tex (to convert it to latex file)
#
# 4. Upload the .tex file to overleaf or render it as pdf to get a version that is format-error free.
#
# 5. (Alternative 1): option is trying to scale the page to fit on the "print" document. This is changing the Scale -> Custom -> Change from 100 to scale that fits on your page. Now, the cell will fit on each extracted page. However, this does not guarantee that all your each cell elements are format error-free.
#
# 6. (Alternative 2): install nbconvert and run `jupyter nbconvert --to pdf PATH_TO_NOTEBOOK`

# %%
# %%capture
# !apt-get update
# !apt-get install -y texlive-xetex texlive-fonts-recommended texlive-plain-generic
# !apt-get install pandoc
# !pip install pypandoc

# %% [markdown]
# Mount your google drive (if on colab)

# %%
# %%capture
import sys
IS_COLAB = 'google.colab' in sys.modules
if IS_COLAB:
  from google.colab import drive
  drive.mount('/content/drive')
  # %cd /content/drive/MyDrive

# %% [markdown]
# Change the file path below to the location of your colab notebook (e.g. `cs189/hw1/fashion_pt_2.ipynb`)

# %%
# %%capture
base_dir = "/content/drive/MyDrive/cs189/hw/hw2" # !TODO
file_name = "arena_warmup.ipynb"         # !TODO
output_name = file_name.split(".")[0] # extract the file name without the extensions
# !jupyter nbconvert --to pdf "{base_dir}/{file_name}" --output "{base_dir}/{output_name}.pdf"

print(f"saved to {base_dir}/{output_name}.pdf")
# Out:
# [NbConvertApp] Converting notebook /content/drive/MyDrive/cs189/hw/hw2/arena_warmup.ipynb to pdf
# [NbConvertApp] Support files will be in /content/drive/MyDrive/cs189/hw/hw2/arena_warmup_files/
# [NbConvertApp] Writing 280000 bytes to notebook.tex
# [NbConvertApp] Building PDF
# [NbConvertApp] Running xelatex 3 times: ['xelatex', 'notebook.tex', '-quiet']
# [NbConvertApp] CRITICAL | xelatex failed: ['xelatex', 'notebook.tex', '-quiet']
# ...

# %%
if IS_COLAB:
  from google.colab import files

  # The path to your PDF file in Google Drive
  pdf_path = f"{base_dir}/{output_name}.pdf"

  # Download the file
  files.download(pdf_path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-2141453767.py in <cell line: 0>()
#       6
#       7   # Download the file
# ----> 8   files.download(pdf_path)
#
# /usr/local/lib/python3.12/dist-packages/google/colab/files.py in download(filename)
#     231   if not _os.path.exists(filename):
#     232     msg = 'Cannot find file: {}'.format(filename)
# --> 233     raise FileNotFoundError(msg)  # pylint: disable=undefined-variable
#     234
#     235   comm_manager = _IPython.get_ipython().kernel.comm_manager
#
# FileNotFoundError: Cannot find file: /content/drive/MyDrive/cs189/hw/hw2/arena_warmup.pdf
